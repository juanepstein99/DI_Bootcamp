# %% [markdown]
# <a href="https://colab.research.google.com/github/juanepstein99/DI_Bootcamp/blob/main/Week7/Day2/Exercise_XP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🌟 Exercise 1: Introduction to Data Analysis
#
# What is data analysis?
# Data analysis is the process of collecting, cleaning, and examining data to find useful information. It helps us understand what is happening by looking at numbers, patterns, and trends. Using data analysis, we can turn raw data into insights that help make better decisions.
#
# Why is data analysis important in modern contexts?
# Data analysis is very important today because we generate a lot of data every day. Companies and organizations use data analysis to make decisions based on facts, not just intuition. It helps reduce risks, improve efficiency, and understand customers better. In many fields, data analysis is key to staying competitive.
#
# Areas where data analysis is applied today
# One area where data analysis is used is business. Companies analyze sales and customer data to improve products and increase profits.
# Another area is healthcare. Hospitals and researchers use data to track diseases, improve treatments, and make better medical decisions.
# A third area is finance. Banks and financial institutions analyze data to detect fraud, manage risk, and predict market trends.

# %% [markdown]
# 🌟Exercise 2: Dataset Loading and Initial Analysis
#
# Objective: Practice dataset loading from Kaggle and initial analysis.
#
# Task:
# * Load the dataset into Jupyter or Google Colab.
# *  Display the first few rows.
# *  Provide a brief dataset description

# %%
import pandas as pd

# * Load the dataset into Jupyter or Google Colab.
df = pd.read_csv('Time_Americans_Spend_Sleeping.csv')

# Display the first few rows.
df.head()

# Provide a brief dataset description
# This dataset shows how much time Americans spend sleeping. It can be used to observe basic sleep patterns across different groups.
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %% [markdown]
# 🌟Exercise 3: Identifying Data Types
#
# Objective: Learn to identify different data types.
# Task:
# *   For the datasets from the previous exercise,
# categorize each column of it as either quantitative or qualitative and explain your reasoning.
#
# Quantitative columns are numbers we can measure, such as year, average hours of sleep, and standard error. Qualitative columns represent categories or labels, such as period, type of days, age group, activity, and sex. The index column is numeric but represents an identifier, not a meaningful variable for analysis.

# %% [markdown]
# 🌟Exercise 4: Exploring Data Types
#
# Objective: Learn about different types of data in data analysis.
#
# Task:
# *   Identify and list which columns in your dataset are qualitative and which are quantitative.
# *   Write a brief description of why each column is classified as qualitative or quantitative.

# %%
import pandas as pd

df = pd.read_csv('Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# Quantitative columns:
#
# * SepalLengthCm: numerical value that represents the length of the sepal.
# * SepalWidthCm: numerical value that represents the width of the sepal.
# * PetalLengthCm: numerical value that represents the length of the petal.
# * PetalWidthCm: numerical value that represents the width of the petal.
#
# These columns are classified as quantitative because they contain numerical measurements that can be compared and analyzed statistically.
#
# Qualitative column
#
# * Species: categorical value that represents the type of flower.
#
# This column is classified as qualitative because it describes categories and not numerical measurements.

# %% [markdown]
# 🌟Exercise 5: Basic Data Analysis with Google Colab
#
# Objective: Perform basic data analysis using Google Colab.
#
# Task:
#
# Using the same notebook from the previous exercise, perform basic data analysis tasks:
#
# * Calculate the mean, median, and mode of a quantitative column.
# * Create a simple plot (like a histogram or bar chart) to visualize the data using Matplotlib/Seaborn libraries
# * Document your findings in the notebook.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('Iris.csv')

# Calculate the mean, median, and mode of a quantitative column.
mean_value = df['SepalLengthCm'].mean()
median_value = df['SepalLengthCm'].median()
mode_value = df['SepalLengthCm'].mode()[0]

mean_value, median_value, mode_value

# Create a simple plot (like a histogram or bar chart) to visualize the data using Matplotlib/Seaborn libraries
plt.hist(df['SepalLengthCm'], bins=20)
plt.title('Distribution of Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Document your findings in the notebook:
#
# In this exercise, the mean, median, and mode were calculated for the SepalLengthCm column to analyze the central tendency of the data. The histogram shows the distribution of sepal length values, which are mostly concentrated around the average.

# %% [markdown]
# 🌟Exercise 6: Basic Observation Skills in Data Analysis
#
# Objective: Develop observation skills for data analysis.
# Task:
#
# * Load the How Much Sleep Do Americans Really Get? dataset into Jupyter or Google Colab.
# * Identify columns that could be interesting for a specific type of analysis and explain your choice.

# %%
# Load the How Much Sleep Do Americans Really Get? dataset into Jupyter or Google Colab.

import pandas as pd
df = pd.read_csv('Time_Americans_Spend_Sleeping.csv')
df.head()
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %% [markdown]
# Identify columns that could be interesting for a specific type of analysis and explain your choice.
#
# **Columns for trend analysis:**
#
# * Year:
#
# This column is useful for trend analysis because it allows us to observe how sleeping time changes over time.
#
# * Avg hrs per day sleeping:
#
# This column is useful because it shows the average number of hours spent sleeping and can be analyzed across different years.
#
# **Columns for group comparison:**
#
# * Age Group:
#
# This column is useful for comparing sleep patterns between different age groups.
#
# * Sex:
#
# This column allows comparison of sleep duration between males and females.
#
# * Type of Days:
#
# This column can be used to compare sleep patterns between weekdays and weekends.
#
# In this dataset, the Year column can be used for trend analysis to observe changes in sleeping habits over time. Columns such as Age Group, Sex, and Type of Days are useful for group comparison because they allow analyzing differences in average sleeping hours between different groups.
